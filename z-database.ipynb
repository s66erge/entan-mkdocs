# %%
# To launch Jupyter Notebook in the current project, run this command in the terminal:
# python -m ipykernel install --user --name myenv
# and select 'entan-mkdocs' as kernel in the Jupyter Notebook interface.

# %%
from fasthtml.common import *
from fastsql import Database # MUST COME AFTER PRECEDING LINE !!!
import libs.dbset as dbset

db = Database("postgresql://postgres:Route666@localhost:5432/postgres")
centers = db.t.center

center = centers["Mahi"]
type(centers)
# Out:
# fastsql.core.DBTable
